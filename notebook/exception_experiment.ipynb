# %%
import sys
import traceback
import os

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Admin\Desktop\LLMOPS\KnowledgeOS\notebook

# %%
import sys
sys.path.append("..")

# %%
from logger.custom_logger import CustomLogger

# %%
logger = CustomLogger().get_logger("exception_experiment")

# %%
class DocumentPortalException(Exception):
    '''Custom Exception for document p[ortal'''
    def __init__(self,error_message:str,error_details:sys):
        _,_,exc_tb=error_details.exc_info()
        self.file_name =  exc_tb.tb_frame.f_code.co_filename
        self.lineno =  exc_tb.tb_lineno
        self.error_message = str(error_message)
        self.traceback_str = "".join(traceback.format_exception(*error_details.exc_info())) 
    def __str__(self):
        return  f'''
                  Error in [{self.file_name}] at line [{self.lineno}]
                  Message: [{self.error_message}]
                  Traceback:
                  [{self.traceback_str}]
                  '''

# %%
if __name__== "__main__":
    try:
        a=1/0
    except Exception as e:
        app_exc = DocumentPortalException(e,sys)
        logger.error(app_exc)
        raise app_exc from None
# Out:
# ---------------------------------------------------------------------------
# DocumentPortalException                   Traceback (most recent call last)
# Cell In[35], line 7
#       3         a=1/0
#       4     except Exception as e:
#       5         app_exc = DocumentPortalException(e,sys)
#       6         logger.error(app_exc)
# ----> 7         raise app_exc from None
#
# DocumentPortalException:
#                   Error in [C:\Users\Admin\AppData\Local\Temp\ipykernel_7712\2285891957.py] at line [3]
#                   Message: [division by zero]
#                   Traceback:
#                   [Traceback (most recent call last):
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_7712\2285891957.py", line 3, in <module>
#     a=1/0
#       ~^~
# ZeroDivisionError: division by zero
# ]
